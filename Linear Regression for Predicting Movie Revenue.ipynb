# %% [markdown]
# Formulate Question -> Gather Data -> Clean Data -> Visualize Data -> Train Algorithm -> Test

# %% [markdown]
# 1.How much revenue can our movie make?

# %% [markdown]
# A lot of factors affect the revenue. The cast, budget, director,marketing,etc.
# It could be noted that big billion dollar movie are the ones where budget matters a lot(for casting,vfx,post-production,etc)

# %% [markdown]
# Hence, let us study a llinear regression betweeen movies' revenue and their budgets

# %% [markdown]
# Question -> Can we use movie budget to <b>predict</b> the movies revenue

# %% [markdown]
# Budget here is provided hence is the given data -> independent var -> Feature
# Revenue                                         -> dependent var   -> Target

# %% [markdown]
# 2. Gather Data

# %%
#Select data sort acc to rank
#format in excel sheet => cntrl + 1

# %%
import pandas as pd
from pandas import DataFrame

# %%
data=pd.read_csv('cost_revenue_clean.csv')

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = DataFrame(data,columns=['production_budget_usd'])  #Budgets
Y = DataFrame(data,columns=['worldwide_gross_usd'])    #Revenue

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,Y,alpha=0.3)
plt.title('Film Budget Vs Global Revenue')
plt.xlabel('Production Budget')
plt.ylabel('Film Revenue')
plt.ylim(0,3000000000)
plt.show()

# %% [markdown]
# ![title](Scr.png)

# %% [markdown]
# ![title](Scr2.png)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X,Y)
# Out:
# LinearRegression()

# %%
regression.coef_ #Slope Coefficient
# Out:
# array([[3.11150918]])

# %%
regression.intercept_ #intercept
# Out:
# array([-7236192.72913963])

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,Y,alpha=0.3)

plt.plot(X,regression.predict(X),color='red',linewidth=3)

plt.title('Film Budget Vs Global Revenue')
plt.xlabel('Production Budget',color='white')
plt.ylabel('Film Revenue',color='white')
plt.ylim(0,3000000000)
plt.show()

# %% [markdown]
# R2 goodness of fit

# %%
    regression.score(X,Y) #statistical measure of how close the data are to the fitted regression line
# Out:
# 0.5496485356985727
